# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pt
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
GII = pd.read_csv("GII.csv") 
GII
# Out:
#            Country  Year  Population  Gini Index  Average Income (USD)  \
# 0    United States  2000    30072337    0.333105          37106.735536
# 1    United States  2001    15189465    0.508761          16250.105075
# 2    United States  2002    89001835    0.229093          40069.586399
# 3    United States  2003   297595139    0.230673           1233.469995
# 4    United States  2004    23680558    0.544657          22950.248061
# ..             ...   ...         ...         ...                   ...
# 355   Saudi Arabia  2019    76352940    0.298362          22142.286345
# 356   Saudi Arabia  2020    59947230    0.300902          23503.216793
# 357   Saudi Arabia  2021     8614363    0.470990          44303.921142
# 358   Saudi Arabia  2022   210722601    0.210066          56770.870968
# 359   Saudi Arabia  2023   165396943    0.364157          65251.308768
#
#      Top 10% Income Share (%)  Bottom 10% Income Share (%)  \
# 0                   30.780946                     1.096329
# 1                   54.563475                     1.441728
# 2                   37.200666                     1.374502
# 3                   40.453246                     4.493424
# 4                   45.343660                     3.250805
# ..                        ...                          ...
# 355                 27.316935                     4.168030
# 356                 51.791266                     1.842205
# 357                 24.308291                     1.967456
# 358                 42.414258                     2.048774
# 359                 30.817990                     2.179214
#
#             Income Group
# 0            High Income
# 1             Low Income
# 2            High Income
# 3    Lower Middle Income
# 4            High Income
# ..                   ...
# 355          High Income
# 356           Low Income
# 357           Low Income
# 358           Low Income
# 359  Lower Middle Income
#
# [360 rows x 8 columns]

# %%
GII.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      360 non-null    object
#  1   Year                         360 non-null    int64
#  2   Population                   360 non-null    int64
#  3   Gini Index                   360 non-null    float64
#  4   Average Income (USD)         360 non-null    float64
#  5   Top 10% Income Share (%)     360 non-null    float64
#  6   Bottom 10% Income Share (%)  360 non-null    float64
#  7   Income Group                 360 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 22.6+ KB

# %%
GII.rename(columns={"Average Income (USD)":"Average Income","Top 10% Income Share (%)":"Top10 IncomeShare%",
                   "Bottom 10% Income Share (%)":"Bottom10 IncomeShare%"},inplace=True)
GII
# Out:
#            Country  Year  Population  Gini Index  Average Income  \
# 0    United States  2000    30072337    0.333105    37106.735536
# 1    United States  2001    15189465    0.508761    16250.105075
# 2    United States  2002    89001835    0.229093    40069.586399
# 3    United States  2003   297595139    0.230673     1233.469995
# 4    United States  2004    23680558    0.544657    22950.248061
# ..             ...   ...         ...         ...             ...
# 355   Saudi Arabia  2019    76352940    0.298362    22142.286345
# 356   Saudi Arabia  2020    59947230    0.300902    23503.216793
# 357   Saudi Arabia  2021     8614363    0.470990    44303.921142
# 358   Saudi Arabia  2022   210722601    0.210066    56770.870968
# 359   Saudi Arabia  2023   165396943    0.364157    65251.308768
#
#      Top10 IncomeShare%  Bottom10 IncomeShare%         Income Group
# 0             30.780946               1.096329          High Income
# 1             54.563475               1.441728           Low Income
# 2             37.200666               1.374502          High Income
# 3             40.453246               4.493424  Lower Middle Income
# 4             45.343660               3.250805          High Income
# ..                  ...                    ...                  ...
# 355           27.316935               4.168030          High Income
# 356           51.791266               1.842205           Low Income
# 357           24.308291               1.967456           Low Income
# 358           42.414258               2.048774           Low Income
# 359           30.817990               2.179214  Lower Middle Income
#
# [360 rows x 8 columns]

# %%
roundoff_columns= ["Gini Index","Top10 IncomeShare%","Bottom10 IncomeShare%","Average Income"]
GII[roundoff_columns] = GII[roundoff_columns].apply(lambda x: round(x,2))

# %%
countries = GII['Country'].unique()
countries
# Out:
# array(['United States', 'India', 'Brazil', 'Germany', 'Nigeria', 'China',
#        'United Kingdom', 'Russia', 'Japan', 'South Africa', 'Canada',
#        'Mexico', 'France', 'Australia', 'Saudi Arabia'], dtype=object)

# %%
developed_countries = ['United States', 'Germany', 'United Kingdom', 'Japan', 'Canada', 
                       'France', 'Australia', 'Saudi Arabia']

GII['Economic Group'] = GII['Country'].apply(lambda x: 'Developed' if x in developed_countries else 'Developing')

# %%
oecd_countries = ['Australia', 'Austria', 'Belgium', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Czechia', 'Denmark', 
    'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 
    'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 
    'Poland', 'Portugal', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Türkiye', 
    'United Kingdom', 'United States']

oecd_key_partners = ['Brazil', 'China', 'India', 'Indonesia', 'South Africa']

GII['OECD Status'] = GII['Country'].apply(lambda x:'Member' if x in oecd_countries else ('Key Partner' if x in oecd_key_partners else 'Non Member'))

# %%
GII
# Out:
#            Country  Year  Population  Gini Index  Average Income  \
# 0    United States  2000    30072337        0.33        37106.74
# 1    United States  2001    15189465        0.51        16250.11
# 2    United States  2002    89001835        0.23        40069.59
# 3    United States  2003   297595139        0.23         1233.47
# 4    United States  2004    23680558        0.54        22950.25
# ..             ...   ...         ...         ...             ...
# 355   Saudi Arabia  2019    76352940        0.30        22142.29
# 356   Saudi Arabia  2020    59947230        0.30        23503.22
# 357   Saudi Arabia  2021     8614363        0.47        44303.92
# 358   Saudi Arabia  2022   210722601        0.21        56770.87
# 359   Saudi Arabia  2023   165396943        0.36        65251.31
#
#      Top10 IncomeShare%  Bottom10 IncomeShare%         Income Group  \
# 0                 30.78                   1.10          High Income
# 1                 54.56                   1.44           Low Income
# 2                 37.20                   1.37          High Income
# 3                 40.45                   4.49  Lower Middle Income
# 4                 45.34                   3.25          High Income
# ..                  ...                    ...                  ...
# 355               27.32                   4.17          High Income
# 356               51.79                   1.84           Low Income
# 357               24.31                   1.97           Low Income
# 358               42.41                   2.05           Low Income
# 359               30.82                   2.18  Lower Middle Income
#
#     Economic Group OECD Status
# 0        Developed      Member
# 1        Developed      Member
# 2        Developed      Member
# 3        Developed      Member
# 4        Developed      Member
# ..             ...         ...
# 355      Developed  Non Member
# 356      Developed  Non Member
# 357      Developed  Non Member
# 358      Developed  Non Member
# 359      Developed  Non Member
#
# [360 rows x 10 columns]

# %%
g20_countries = ['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany', 
                 'India', 'Indonesia', 'Italy', 'Japan', 'Republic of Korea', 'Mexico', 'Russia', 
                 'Saudi Arabia', 'South Africa', 'Türkiye', 'United Kingdom', 'United States']

# List of EU member countries
eu_countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark',
                'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 
                'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia',
                'Slovenia', 'Spain', 'Sweden']

def classify_country(country):
    if country in g20_countries:
        return 'G20 Member'
    elif country in eu_countries:
        return 'EU Member'
    else:
        return 'Non G20 Member'

GII['G20/EU Status'] = GII['Country'].apply(classify_country)

# %%
def classify_region(country):
    if country in ['United States', 'Canada', 'Mexico']:
        return 'North America'
    elif country in ['Brazil', 'Argentina', 'Chile', 'Colombia', 'Peru']:
        return 'Latin America and the Caribbean'
    elif country in ['United Kingdom', 'France', 'Germany', 'Netherlands', 'Belgium', 
                     'Sweden', 'Norway', 'Finland', 'Denmark', 'Austria', 'Switzerland', 
                     'Ireland', 'Spain', 'Portugal', 'Italy']:
        return 'Western Europe'
    elif country in ['Russia', 'Ukraine', 'Poland', 'Hungary', 'Czech Republic', 'Slovakia', 
                     'Lithuania', 'Latvia', 'Estonia', 'Kazakhstan', 'Uzbekistan']:
        return 'Eastern Europe and Central Asia'
    elif country in ['China', 'Japan', 'South Korea', 'Mongolia', 'Taiwan']:
        return 'East Asia'
    elif country in ['India', 'Indonesia', 'Thailand', 'Malaysia', 'Philippines', 'Vietnam']:
        return 'Southeast Asia'
    elif country in ['Saudi Arabia', 'Egypt', 'Iran', 'Turkey', 'Iraq', 'United Arab Emirates']:
        return 'Middle East and North Africa'
    elif country in ['Nigeria', 'South Africa', 'Kenya', 'Ghana', 'Uganda', 'Tanzania']:
        return 'Sub-Saharan Africa'
    elif country in ['Australia', 'New Zealand', 'Papua New Guinea']:
        return 'Oceania'
    else:
        return 'Other'

GII['Regional Group'] = GII['Country'].apply(classify_region)

# %%
GII
# Out:
#            Country  Year  Population  Gini Index  Average Income  \
# 0    United States  2000    30072337        0.33        37106.74
# 1    United States  2001    15189465        0.51        16250.11
# 2    United States  2002    89001835        0.23        40069.59
# 3    United States  2003   297595139        0.23         1233.47
# 4    United States  2004    23680558        0.54        22950.25
# ..             ...   ...         ...         ...             ...
# 355   Saudi Arabia  2019    76352940        0.30        22142.29
# 356   Saudi Arabia  2020    59947230        0.30        23503.22
# 357   Saudi Arabia  2021     8614363        0.47        44303.92
# 358   Saudi Arabia  2022   210722601        0.21        56770.87
# 359   Saudi Arabia  2023   165396943        0.36        65251.31
#
#      Top10 IncomeShare%  Bottom10 IncomeShare%         Income Group  \
# 0                 30.78                   1.10          High Income
# 1                 54.56                   1.44           Low Income
# 2                 37.20                   1.37          High Income
# 3                 40.45                   4.49  Lower Middle Income
# 4                 45.34                   3.25          High Income
# ..                  ...                    ...                  ...
# 355               27.32                   4.17          High Income
# 356               51.79                   1.84           Low Income
# 357               24.31                   1.97           Low Income
# 358               42.41                   2.05           Low Income
# 359               30.82                   2.18  Lower Middle Income
#
#     Economic Group OECD Status G20/EU Status                Regional Group
# 0        Developed      Member    G20 Member                 North America
# 1        Developed      Member    G20 Member                 North America
# 2        Developed      Member    G20 Member                 North America
# 3        Developed      Member    G20 Member                 North America
# 4        Developed      Member    G20 Member                 North America
# ..             ...         ...           ...                           ...
# 355      Developed  Non Member    G20 Member  Middle East and North Africa
# 356      Developed  Non Member    G20 Member  Middle East and North Africa
# 357      Developed  Non Member    G20 Member  Middle East and North Africa
# 358      Developed  Non Member    G20 Member  Middle East and North Africa
# 359      Developed  Non Member    G20 Member  Middle East and North Africa
#
# [360 rows x 12 columns]

# %%
GII.to_csv('GII_data.csv', index=False)

# %%
GII.describe()
# Out:
#               Year    Population  Gini Index  Average Income  \
# count   360.000000  3.600000e+02  360.000000      360.000000
# mean   2011.500000  1.722251e+08    0.425611    35433.844639
# std       6.931821  1.016954e+08    0.128098    20425.341258
# min    2000.000000  5.493471e+06    0.200000     1031.460000
# 25%    2005.750000  7.873280e+07    0.320000    18655.895000
# 50%    2011.500000  1.754913e+08    0.430000    34470.820000
# 75%    2017.250000  2.541225e+08    0.540000    54259.992500
# max    2023.000000  3.491768e+08    0.650000    69732.710000
#
#        Top10 IncomeShare%  Bottom10 IncomeShare%
# count          360.000000             360.000000
# mean            40.200389               2.992611
# std             11.495397               1.147500
# min             20.050000               1.020000
# 25%             30.487500               1.995000
# 50%             40.390000               2.975000
# 75%             49.917500               4.025000
# max             59.940000               4.990000
